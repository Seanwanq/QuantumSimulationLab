# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
from quantumsimulationlab.enums import (
    CoherentOrientationEnum,
    PreparedHamiltonianEnum,
    GateTypeEnum,
    PauliEnum,
)

# %%
GateTypeEnum.Id.value
# Out:
# '124'
